# %%
# Importing relevant libraries and defining the Net class (same class with which the networks were generated)
import torch
import torch.nn as nn 
import torch.nn.functional as F
import pickle
from numpy.random import RandomState
import numpy as np
from sklearn.svm import LinearSVC
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
from torchvision import datasets, transforms

# %%
# Network class
k=1
class Net(torch.nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layers = nn.ModuleList()
        
        self.layers+=[nn.Sequential(nn.Conv2d(3, 16*k,  kernel_size=3) , nn.BatchNorm2d(16*k),
                      nn.ReLU(inplace=True)), nn.Sequential(nn.Conv2d(16*k, 16*k,  kernel_size=3) , nn.BatchNorm2d(16*k),
                      nn.ReLU(inplace=True))] 
        self.layers+=[nn.Sequential(nn.Conv2d(16*k, 32*k,  kernel_size=3, stride=2),  nn.BatchNorm2d(32*k),
                      nn.ReLU(inplace=True))]
        self.layers+=[nn.Sequential(nn.Conv2d(32*k, 32*k,  kernel_size=3),  nn.BatchNorm2d(32*k),
              nn.ReLU(inplace=True)),nn.Sequential(nn.Conv2d(32*k, 32*k,  kernel_size=3),  nn.BatchNorm2d(32*k),
              nn.ReLU(inplace=True))]
        self.layers+=[nn.Sequential(nn.Conv2d(32*k, 64*k,  kernel_size=3, stride=2), nn.BatchNorm2d(64*k),
                      nn.ReLU(inplace=True))]
        self.layers+=[nn.Sequential(nn.Conv2d(64*k, 64*k,  kernel_size=3, padding='valid'), nn.BatchNorm2d(64*k),
                      nn.ReLU(inplace=True))]
        self.layers+=[nn.Sequential(nn.Conv2d(64*k, 64*k,  kernel_size=1), nn.BatchNorm2d(64*k),
                      nn.ReLU(inplace=True))]
        self.layers+= [nn.AdaptiveAvgPool2d((1,1))]
        self.fc = nn.Linear(64*k, 10)
    
    def forward(self, x, acts_only=False,all_act=False):
        all_acts = []
        for i in range(len(self.layers)):
            all_acts.append(x)
            x = self.layers[i](x)

        x = self.fc(x.view(-1, 64*k))

        if all_act:
            # all_cts does not return the final output of the network
            return all_acts, x
        return x
    
# Defining linear CKA
class LinCKA(nn.Module):
    def __init__(self, n=1000):
        super(LinCKA, self).__init__()
        self.resetK(n)
    
    def resetK(self,n):
        unit = torch.ones([n, n])
        I = torch.eye(n)
        H = I - unit / n
        H = H.cuda()
        self.H = H.cuda()
        self.n = n

    def centering(self, K):
        H = self.H
        return torch.matmul(torch.matmul(H, K), H) 

    def linear_HSIC(self, X, Y):
        L_X = torch.matmul(X, X.T)
        L_Y = torch.matmul(Y, Y.T)
        return torch.sum(self.centering(L_X) * self.centering(L_Y))

    def linear_CKA(self,X, Y):
        hsic = self.linear_HSIC(X, Y)
        var1 = torch.sqrt(self.linear_HSIC(X, X))
        var2 = torch.sqrt(self.linear_HSIC(Y, Y))

        return hsic / (var1 * var2),var1,var2

    def forward(self, X,Y):
        if len(X) != self.n:
            self.resetK(len(X))
        return self.linear_CKA(X,Y)

# %%
# Import data 
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                  std=[0.229, 0.224, 0.225])

transform_val = transforms.Compose([transforms.ToTensor(), normalize]) 
transform_train =  transforms.Compose([transforms.ToTensor(), normalize]) 
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

##### Cifar Data
cifar_data = datasets.CIFAR10(root='.',train=True, transform=transform_train, download=True)
cifar_data_test = datasets.CIFAR10(root='.',train=False, transform=transform_val, download=True)
n=10000
val_loaderx = torch.utils.data.DataLoader(cifar_data_test,
                                           batch_size=n, 
                                           shuffle=False)
data, labels = iter(val_loaderx).next()
data = data.to(device)

train_loaderx = torch.utils.data.DataLoader(cifar_data,
                                           batch_size=50000, 
                                           shuffle=False)
train_data, train_labels = iter(train_loaderx).next()
train_data = train_data.to(device)
train_labels = train_labels.detach().cpu().numpy()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Importing the saved networks
PATH='net_kornblith/net_kornblith_'

# net_rand1 = Net()
# net_rand1.load_state_dict(torch.load(PATH+'random_1.zip'))
# net_rand1.eval()
# net_rand1.cuda()

# net_rand2 = Net()
# net_rand1.load_state_dict(torch.load(PATH+'random_2.zip'))
# net_rand2.eval()
# net_rand2.cuda()

net_all1 = Net()
net_all1.load_state_dict(torch.load(PATH+'all_1.zip'))
net_all1.eval()
net_all1.cuda()

# net_all2 = Net()
# net_all2.load_state_dict(torch.load(PATH+'all_2.zip'))
# net_all2.eval()
# net_all2.cuda()

# net_mem_s1 = Net()
# net_mem_s1.load_state_dict(torch.load(PATH+'mem_1_set1.zip'))
# net_mem_s1.eval()
# net_mem_s1.cuda()

# net_mem_s2 = Net()
# net_mem_s2.load_state_dict(torch.load(PATH+'mem_2_set2.zip'))
# net_mem_s2.eval()
# net_mem_s2.cuda()
# Out:
# Net(
#   (layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (2): Sequential(
#       (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (3): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (4): Sequential(
#       (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (5): Sequential(
#       (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (6): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=valid)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (7): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (fc): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# # Splitting experiment

# %% [markdown]
# ## Functions

# %%
def get_activations_by_class(data, labels):
    indexes = []
    datapoints = []
    
    for label in range(10): #for label in set(labels): 
        indexes.append(np.where(labels==label))
        datapoints.append(data[indexes[-1]])
    
    return datapoints, np.array(indexes).squeeze()

def split_class_clusters(data, indexes, d, W, n_clusters, split_constant):
    # data should be of shape n x d (n examples, d features)
    # d is the random direction vector
    # W comes from lin_svc.coef_ (n_classes, n_features) corresponding to the normal vectors to the decision hyperplanes
    data_ = np.copy(data)
    
    Q, R = np.linalg.qr(W.T)
    d_ = d.reshape([1,np.max(d.shape)])
    d_ -= np.matmul(d_, np.matmul(Q, Q.T))
    
    projections = np.matmul(data_, d_.T).squeeze()
    mean = np.mean(projections)
    min_ = np.min(projections)
    max_ = np.max(projections)
    
    translations = np.zeros(data_.shape[0])
    
    idxs = []
    separators = np.linspace(min_,max_,n_clusters+1)
    for cluster_idx in range(n_clusters):
        idx = np.where(projections>=separators[cluster_idx])
        if cluster_idx < (n_clusters-1): # Except for last cluster we need to take into account that the projections are not superior to the next separator
            idx2 = idx2 = np.where(projections<separators[cluster_idx+1])
            idx = np.intersect1d(idx, idx2)
        idxs.append(idx)
        translations[idxs[-1]] = cluster_idx*split_constant 
    
    translations = np.matmul(np.diag(translations.squeeze()), np.matmul(np.ones([data_.shape[0],1]), d_))
    
    data_+= translations
    return data_, np.array([indexes[i] for i in idxs]).squeeze()

def test_cka_lin_sep(data_per_classes, indexes, lin_svc,
                     num_clusters = 2,
                     dist_clusters = 100,
                     splitting_dir='pc4',
                     num_pts_cka = 10000,
                     seed = 0):
    np.random.seed(seed)
    
    print('Number of clusters: {}; Distance between clusters: {}; Splitting direction: '.format(num_clusters, dist_clusters)+splitting_dir+'; Number of points to compute CKA: {}'.format(num_pts_cka))
    
    labels = np.zeros(len(data_per_classes[0]))
    split_data = []
    split_indexes = []
    
    # Iterate the splitting for each class
    for class_idx, class_data in enumerate(data_per_classes):
        
        # Define the direction along which to split the data
        if 'pc' in splitting_dir:
            direction = PCA(n_components = int(splitting_dir[2:])).fit(class_data).components_[int(splitting_dir[2:])-1]
        if splitting_dir == 'random':
#             # Sample from un-centered cube (not to be used)
#             direction = np.random.rand(1, class_data.shape[1])
#             # Sample from sphere using cubes (takes way to much time)
#             while np.linalg.norm(direction)> 1:
#                 direction = np.random.rand(1, class_data.shape[1])
#                 direction = direction/np.linalg.norm(direction)
            direction = np.random.normal(0, 1, class_data.shape[1])
            norm = np.sum(direction**2)**(0.5)
            direction = direction/norm
        
        # Split the data
        splits = split_class_clusters(class_data, indexes[class_idx], direction, lin_svc.coef_, num_clusters, dist_clusters)
        split_data.append(splits[0])
        split_indexes.append([i for i in splits[1]])
        if class_idx != 0: labels = np.concatenate([labels, class_idx*np.ones(split_data[-1].shape[0])])
        
    split_data = np.concatenate(split_data)
    original_data = torch.Tensor(np.concatenate(data_per_classes)).cuda()
    
    lin_sep = lin_svc.score(split_data, labels)
    print("Accuracy of the linear SVM classifier on the split data: {}".format(lin_sep))
    
    split_data = torch.Tensor(split_data).cuda()
    # CKA values
    CKA = LinCKA()
    perm = np.random.permutation(num_pts_cka)
    cka = CKA(original_data[perm], split_data[perm])[0].item()
    print("Cka between {} original vs split pts: {}".format(num_pts_cka, cka))
    return lin_sep, cka

# %% [markdown]
# ## Generate the data

# %%
train_activations, _ = net_all1.forward(train_data, all_act=True)
train_act = train_activations[-1].reshape(train_activations[-1].shape[0],-1).detach().cpu().numpy()
for i in train_activations: del i
del train_activations

# Linear separability:
lin_svc = LinearSVC()
lin_svc.fit(train_act, train_labels)
original_lin_sep = lin_svc.score(train_act, train_labels)
print("Accuracy of a linear SVM classifier on the original data: {}".format(original_lin_sep))
# Out:
# Accuracy of a linear SVM classifier on the original data: 0.91468
# /cvmfs/ai.mila.quebec/apps/x86_64/debian/anaconda/3/lib/python3.7/site-packages/sklearn/svm/base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
data_per_classes, indexes = get_activations_by_class(train_act, train_labels)

data = {'lin_sep_original': original_lin_sep}
for num_pts_cka in [1000, 5000, 10000, 20000]:
    data[str(num_pts_cka)] = {}
    
    for direction in ['pc10', 'pc30', 'pc50', 'pc500', 'random0', 'random1']:
        data[str(num_pts_cka)][direction] = {}
        
        for num_clusters in [2, 5, 10, 50]:
            data[str(num_pts_cka)][direction][str(num_clusters)] = {}
            
            for dist_clusters in [10, 100, 1000, 10000]:
                lin_sep, cka = test_cka_lin_sep(data_per_classes, indexes, lin_svc, num_clusters = num_clusters, dist_clusters = dist_clusters, splitting_dir = direction[:-1], num_pts_cka = num_pts_cka, seed = int(direction[-1]))
                data[str(num_pts_cka)][direction][str(num_clusters)][str(dist_clusters)] = {'lin_sep': lin_sep, 'cka': cka}
                
                # Put the data saving here so it saves where it's at after each step
                with open('data/split_class_exp_train_v1.pkl', 'wb') as f:
                    pickle.dump(data, f)
# Out:
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.9103221893310547
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.4663065969944
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.38388583064079285
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.37661871314048767
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.8214760422706604
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.6390326023101807
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.6249280571937561
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.623810887336731
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.7625110149383545
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.6880767345428467
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.6852567195892334
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.6850780248641968
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.7130186557769775
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.7080696225166321
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.7079981565475464
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc1; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91466
# Cka between 1000 original vs split pts: 0.7079959511756897
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.7923407554626465
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.19439788162708282
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.16486893594264984
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.16361413896083832
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.6172367930412292
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.2374822348356247
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.22632259130477905
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.22593732178211212
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.4150025546550751
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.2550961375236511
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.25220298767089844
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.25213122367858887
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.2715003192424774
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.261840283870697
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.26172971725463867
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc3; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91472
# Cka between 1000 original vs split pts: 0.2617281675338745
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.8805549144744873
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.15268734097480774
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.11606361716985703
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1151038333773613
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.6477990746498108
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.15807966887950897
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1458921879529953
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.14560745656490326
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.3768859803676605
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.17010417580604553
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.16685500741004944
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91466
# Cka between 1000 original vs split pts: 0.1667976677417755
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.18697024881839752
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1750977486371994
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.17496894299983978
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.17496751248836517
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.8886548280715942
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.041632670909166336
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.016900381073355675
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.01661401055753231
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.7106939554214478
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.04065919294953346
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.028572166338562965
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.028436962515115738
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.32302340865135193
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.03310640901327133
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.029573023319244385
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.02953398786485195
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.04791603609919548
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.03332645446062088
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.033176030963659286
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.9147
# Cka between 1000 original vs split pts: 0.0331745445728302
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.8856199383735657
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1363440454006195
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.11352530121803284
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.11315196007490158
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.6973416805267334
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.15521349012851715
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.14543454349040985
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.14529141783714294
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.3820612132549286
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.16536101698875427
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.16267666220664978
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1626414656639099
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1824796199798584
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1719570755958557
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1718483418226242
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91466
# Cka between 1000 original vs split pts: 0.17184704542160034
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.8810288310050964
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.13096097111701965
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.10884402692317963
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.10851159691810608
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.7069495916366577
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1322445571422577
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1217765286564827
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.12162909656763077
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.3774753510951996
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.14167335629463196
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.1387588381767273
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.13872240483760834
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.15819227695465088
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.14653809368610382
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.14641818404197693
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 1000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 1000 original vs split pts: 0.146417036652565
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.9122974276542664
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.4833711087703705
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.39994001388549805
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.3923766613006592
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.8330559730529785
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.6624998450279236
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.6485608220100403
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.6474242210388184
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.7815732359886169
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.7127036452293396
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.7099446654319763
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.7097623944282532
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.737969160079956
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.7335371375083923
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.733473539352417
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc1; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91466
# Cka between 5000 original vs split pts: 0.7334715127944946
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.7953290939331055
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.1816248893737793
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.1520175039768219
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.1508156806230545
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.6209917664527893
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.22115765511989594
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.2095354199409485
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.20915135741233826
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.4071408212184906
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.23791174590587616
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.234878271818161
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.23480568826198578
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.25484371185302734
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.24465230107307434
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.24453707039356232
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc3; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91472
# Cka between 5000 original vs split pts: 0.2445356398820877
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.876787543296814
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.14478060603141785
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.10879482328891754
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.10786112397909164
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.6506984829902649
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.15608221292495728
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.14387506246566772
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.14360418915748596
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.37508508563041687
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.1646738499403
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.16139471530914307
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91466
# Cka between 5000 original vs split pts: 0.16133908927440643
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.17967164516448975
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.1676199734210968
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.16748762130737305
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.16748616099357605
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.8901990652084351
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.0466110035777092
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.021876923739910126
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.021594209596514702
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.7261826395988464
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.03878087177872658
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.026141786947846413
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.026000279933214188
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.34574928879737854
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.034014612436294556
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.03019656613469124
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.03015604056417942
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.047014810144901276
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.03128461912274361
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.031122347339987755
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.9147
# Cka between 5000 original vs split pts: 0.031120603904128075
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.890642523765564
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.14483284950256348
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.12166282534599304
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.12129585444927216
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.6978872418403625
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.151702418923378
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.14188918471336365
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.1417454183101654
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.38717907667160034
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.16451124846935272
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.1617652326822281
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.16173017024993896
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.17884695529937744
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.16787253320217133
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.16775929927825928
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91466
# Cka between 5000 original vs split pts: 0.16775821149349213
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.8852511048316956
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.11964951455593109
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.09688356518745422
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.09653951227664948
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.7236242890357971
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.12775367498397827
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.11663292348384857
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.11647771298885345
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.3894881308078766
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.13863706588745117
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.13551829755306244
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.1354791522026062
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.15606631338596344
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.14354059100151062
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.14341138303279877
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 5000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 5000 original vs split pts: 0.1434100717306137
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc1; Number of points to compute CKA: 10000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 10000 original vs split pts: 0.9555069208145142
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc1; Number of points to compute CKA: 10000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 10000 original vs split pts: 0.51230788230896
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc1; Number of points to compute CKA: 10000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 10000 original vs split pts: 0.3806883692741394
# ...
# Accuracy of the linear SVM classifier on the split data: 0.91472
# Cka between 20000 original vs split pts: 0.5944207310676575
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.9625946283340454
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.31426355242729187
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.26452410221099854
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.2644820809364319
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.7634806632995605
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5312772393226624
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.530742883682251
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5310871601104736
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.6128098368644714
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5528338551521301
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5535795092582703
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91466
# Cka between 20000 original vs split pts: 0.5537346005439758
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.563555121421814
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5634698867797852
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5637108683586121
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc5; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5637376308441162
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.9749910831451416
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.31691262125968933
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.26776623725891113
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.26710259914398193
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.7876605987548828
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5525862574577332
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5485943555831909
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5485409498214722
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.6362702250480652
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5685135126113892
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5676583647727966
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5676388740539551
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5773679614067078
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5746007561683655
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5745499134063721
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: pc50; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.9147
# Cka between 20000 original vs split pts: 0.5745464563369751
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.9673494696617126
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.3085472583770752
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.2799863815307617
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.28029629588127136
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.7050574421882629
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.4818727970123291
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.4813905358314514
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.4816547930240631
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5553395748138428
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.504818320274353
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5054230690002441
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5055359601974487
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5183709263801575
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.518452525138855
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5186600089073181
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91466
# Cka between 20000 original vs split pts: 0.518683671951294
# Number of clusters: 2; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.9695538878440857
# Number of clusters: 2; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.33086973428726196
# Number of clusters: 2; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.3046809434890747
# Number of clusters: 2; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.3054659068584442
# Number of clusters: 5; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.7546175122261047
# Number of clusters: 5; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5479024052619934
# Number of clusters: 5; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.548654317855835
# Number of clusters: 5; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5490313768386841
# Number of clusters: 10; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.6136573553085327
# Number of clusters: 10; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5678699612617493
# Number of clusters: 10; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5690432190895081
# Number of clusters: 10; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5692223310470581
# Number of clusters: 50; Distance between clusters: 10; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5770781636238098
# Number of clusters: 50; Distance between clusters: 100; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5781738758087158
# Number of clusters: 50; Distance between clusters: 1000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5784891247749329
# Number of clusters: 50; Distance between clusters: 10000; Splitting direction: random; Number of points to compute CKA: 20000
# Accuracy of the linear SVM classifier on the split data: 0.91468
# Cka between 20000 original vs split pts: 0.5785238742828369

# %% [markdown]
# ## Analyse the data

# %%
with open('data/split_class_exp_train_v1.pkl', 'rb') as f:
    data = pickle.load(f)
    
num_clusters = [2, 5, 10, 50]
dist_clusters = [10, 100, 1000, 10000]

for num_pts_cka in [1000, 5000, 10000, 20000]:
    for direction in ['pc10', 'pc30', 'pc50', 'pc500', 'random0', 'random1']:
        cka_values = np.array([[data[str(num_pts_cka)][direction][str(i)][str(j)]['cka'] for j in dist_clusters] for i in num_clusters])        
        fig = plt.figure()
        ax = fig.add_subplot(111)
        cax = ax.imshow(cka_values, interpolation ='nearest', vmin=0, vmax=1)
        fig.colorbar(cax)
        dirr = direction[:-1]
        if 'random' in dirr: dirr = direction
        ax.set_title('Direction '+dirr+'; CKA # pts {}'.format(num_pts_cka))
        ax.set_xticks(np.arange(len(dist_clusters)))
        ax.set_yticks(np.arange(len(num_clusters)))
        ax.set_xticklabels([str(i) for i in dist_clusters])
        ax.set_yticklabels([str(i) for i in num_clusters])
        ax.axis('image')
        plt.tight_layout()
        plt.savefig('figures/split_exp_figures_v1/split_class_exp_train_{}pts_'.format(num_pts_cka)+dirr+'.png')
# Out:
# /cvmfs/ai.mila.quebec/apps/x86_64/debian/anaconda/3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   # Remove the CWD from sys.path while we load stuff.
